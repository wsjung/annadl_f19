# %% [markdown]
# > **DO NOT EDIT IF INSIDE annadl_f19 folder**

# %% [markdown]
# # Week 5: Recurrent neural networks
#
# Text, speech, weather, sensor output and video are but a few examples of the many types of data that is inherently sequential. So how does one predict the next word in a sentence, future temperatures or missing video frames? Using **recurrent neural networks** (RNNs)!

# %%
# %matplotlib inline

import numpy as np
import requests as rq
import random
import sys
import io
from bs4 import BeautifulSoup
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import RMSprop

# %% [markdown]
# ## Exercises

# %% [markdown]
# #### Modeling text

# %% [markdown]
# Text prediction is a good place to start when learning about RNNs, because most of us humans have a pretty well
# optimized inner model for text prediction ourselves. We can, therefore, easily assess the performance of a neural
# network in executing this task.
#
# Below is some code that loads the screenplay for Tarantino's 1994 film 'Pulp Fiction'. I recommend reading through the
# first 20 lines or so to get a feeling for the language and style used (and enjoy probably the best written screenplay
# in the history of film).

# %%
response = rq.get("http://www.dailyscript.com/scripts/pulp_fiction.html")
text = BeautifulSoup(response.content, "html.parser").getText()
print(text[:2000])
# Out:
# "PULP FICTION" -- by Quentin Tarantino & Roger Avary
#
#
#                                       "PULP FICTION"
#
#                                             By
#
#                              Quentin Tarantino & Roger Avary
#
#
#
#                PULP [pulp] n.
#
#                1. A soft, moist, shapeless mass or matter.
#
#                2. A magazine or book containing lurid subject matter and
#                being characteristically printed on rough, unfinished paper.
#
#                American Heritage Dictionary: New College Edition
#
#                INT. COFFEE SHOP – MORNING
#
#                A normal Denny's, Spires-like coffee shop in Los Angeles.
#                It's about 9:00 in the morning. While the place isn't jammed,
#                there's a healthy number of people drinking coffee, munching
#                on bacon and eating eggs.
#
#                Two of these people are a YOUNG MAN and a YOUNG WOMAN. The
#                Young Man has a slight working-class English accent and,
#                like his fellow countryman, smokes cigarettes like they're
#                going out of style.
#
#                It is impossible to tell where the Young Woman is from or
#                how old she is; everything she does contradicts something
#                she did. The boy and girl sit in a booth. Their dialogue is
#                to be said in a rapid pace "HIS GIRL FRIDAY" fashion.
#
#                                      YOUNG MAN
#                          No, forget it, it's too risky. I'm
#                          through doin' that shit.
#
#                                      YOUNG WOMAN
#                          You always say that, the same thing
#                          every time: never again, I'm through,
#                          too dangerous.
#
#                                      YOUNG MAN
#                          I know that's what I always say. I'm
#                          always right too, but –

# %% [markdown]
# > **Ex. 5.1.1:** What is the most used symbol in this screenplay and what accuracy would a model constantly predicting this symbol obtain? In other words, what is the "baseline accuracy"?

# %%
char_freqs = {}

for symbol in text:
    if symbol in char_freqs:
        char_freqs[symbol] += 1
    else:
        char_freqs[symbol] = 1

freqs = 0       
i=0
max_freq = 0
        
for symbol in sorted(char_freqs, key=char_freqs.get, reverse=True):
    freqs += char_freqs[symbol]
    if i==0:
        print("max freq letter: %s with %d occurences" % (repr(symbol), char_freqs[symbol]))
        max_freqs = freqs
    i+=1
    
acc = max_freqs / freqs
print("baseline accuracy: %f" % acc)
# Out:
# max freq letter: ' ' with 164787 occurences
# baseline accuracy: 0.541059

# %% [markdown]
# I've adapted some code for text generation from [this Keras example](https://keras.io/examples/lstm_text_generation/).
# I've inserted some questions in the code (look for `Q:`) for you to answer in the exercise below.

# %%
# Q1: What is the purpose of this block? When is `char_indices` used? What about `indices_char`?
# A1: char_indices is a dictionary of the characters keyed by the characters and indices_char is keyed by the indices
chars = sorted(list(set(text)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# Q2: What is the purpose of this block? What does the `seqlen` and `step` parameters do?
# A2: seqlen specifies the length of the sequence for each iteration and the step parameter specifies the number of elements to skip
seqlen = 40
step = seqlen
sentences = []
for i in range(0, len(text) - seqlen - 1, step):
    sentences.append(text[i: i + seqlen + 1])

# Q3: What about this block? What is `x` and what is `y`? Why do they have this dimensionality?
# A3: `x` is the current character and `y` is the next character
x = np.zeros((len(sentences), seqlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), seqlen, len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    # Q3a: What happens in this loop?
    # A3a: assigns 1 to the current char and the next char
    for t, (char_in, char_out) in enumerate(zip(sentence[:-1], sentence[1:])):
        x[i, t, char_indices[char_in]] = 1
        y[i, t, char_indices[char_out]] = 1


# Q4: Here we build the model. What does the `return_sequences` argument do? Why the dense layer at the end?
# A4: returns the full output sequence
model = Sequential()
model.add(LSTM(128, input_shape=(seqlen, len(chars)), return_sequences=True))
model.add(Dense(len(chars), activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer=RMSprop(lr=0.01),
    metrics=['categorical_crossentropy', 'accuracy']
)

def sample(preds, temperature=1.0):
    """Helper function to sample an index from a probability array."""
    preds = np.asarray(preds).astype('float64')
    preds = np.exp(np.log(preds) / temperature)  # softmax
    preds = preds / np.sum(preds)                #
    probas = np.random.multinomial(1, preds, 1)  # sample index
    return np.argmax(probas)                     #


def on_epoch_end(epoch, _):
    """Function invoked at end of each epoch. Prints generated text."""
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - seqlen - 1)
    
    # Q5: What does diversity do?
    for diversity in [0.2, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + seqlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, seqlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.
            
            # What is the dimensionality of `preds`? Why do we input `preds[0, -1]` to the `sample` function?
            preds = model.predict(x_pred, verbose=0)
            next_index = sample(preds[0, -1], diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=50,
          callbacks=[print_callback])
# Out:
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/50
# 7614/7614 [==============================] - 8s 1ms/step - loss: 2.1768 - categorical_crossentropy: 2.1768 - acc: 0.5464
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: " blows out the match.
#
#                "
#  blows out the match.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " blows out the match.
#
#                "
#  blows out the match.
#
#                                          d mend thenther, bint                                                                                                                  a                              the
#
#                                                                                                                      nn  a                                                     a  anlontend the dind gha
# ----- diversity: 1.0
# ----- Generating with seed: " blows out the match.
#
#                "
#  blows out the match.
#
#                  heuned aie OorcRs)
# 'T SoU't. wondat,ins rr
#
#
#   enar ehaveaivand ewhet at o.sum.e
# s nn myit   thcankena,relsnv duythaghis
#
# t   i WBw oduu sutlajteshe kithaa"wasyeehelytsser se  doujAatreateokaokov ce theata.nauud!
# h  d U         q  i to.h.ind aenitcoh, g-gelrarsh
#
# auk.
#
#       houctsontsstgat.
#
#
#     F!
#
#    te gam,anchiD,,akdwe.
#
#     sn'   hmarn t, bt  re  unc inccootco .
#
# Epoch 2/50
# 7614/7614 [==============================] - 6s 775us/step - loss: 1.4122 - categorical_crossentropy: 1.4122 - acc: 0.6359
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "r knees. Blood begins to drip from Mia's"
# r knees. Blood begins to drip from Mia's and the the the douthe the the the the the the the the the the the the the the the the the the the the thes to the the the the the the the the the the the the tore the the the ther in the the the the the the the the touthe the the the the the the the the the the the the sithes the the the the the the tolllllllllllous the the the tore the the here the the the the the the the the fing the the the t
# ----- diversity: 0.5
# ----- Generating with seed: "r knees. Blood begins to drip from Mia's"
# r knees. Blood begins to drip from Mia's the the the the thet wathe wathit's and are the tolle the the keringe and the wave ting the the pores ardes the wathet then the heas aring bing the the the at sper wather tore
#
# ----- diversity: 1.0
# ----- Generating with seed: "r knees. Blood begins to drip from Mia's"
# r knees. Blood begins to drip from Mia's qupames.
#
#       therywallide a mang.
#
#                    VINCENCELE
#     MARSHMIRCENREM–
# RULLDn   VALCES
#                 Whast.
#
#                      JULHS
#                           I JuDdrokvain't Wa clalkle figking aalontpoon'tlot. dousss, herhaniogzeocks
#
#           as ttoliteersrin fosh ighatchrab'lantaway a berthenow. whes theztro-
#         iceret ardrofides algtatkoongve Jpcesteri
# Epoch 3/50
# 7614/7614 [==============================] - 6s 745us/step - loss: 1.2177 - categorical_crossentropy: 1.2177 - acc: 0.6767
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "                                FABIENNE"
#                                 FABIENNE
#
# ----- diversity: 0.5
# ----- Generating with seed: "                                FABIENNE"
#                                 FABIENNE
#
# ----- diversity: 1.0
# ----- Generating with seed: "                                FABIENNE"
#                                 FABIENNE
#           topoutlale, no and is the sit's it the
#                                    Wher,
#                    s a tve's is Jaligs.
#
#                               goook mar me up to uils, ligon.
#
#                        ou gosert.
#
#               JULES A                             snat aake3s thes yaue teele, tiisell. Thand
#                       Thens tae as thpey proppas go sale a ward
# Epoch 4/50
# 7614/7614 [==============================] - 7s 873us/step - loss: 1.1192 - categorical_crossentropy: 1.1192 - acc: 0.7007
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "                                     JUL"
#                                      JULES
#
# ----- diversity: 0.5
# ----- Generating with seed: "                                     JUL"
#                                      JULES
#
# ----- diversity: 1.0
# ----- Generating with seed: "                                     JUL"
#                                      JULES
#                       Mianiellugely witch sell?
#
#                          rithout dighamaty, you had-swoll of that'm his don't
#                                                   OPPAKTRID (OO...)
#                      thit I god alLully's PUTSE froming to kire orour
#             A I man't grolly.
#
#                                    Purkin – UT. MUN WOMMAF
#
# Epoch 5/50
# 7614/7614 [==============================] - 7s 928us/step - loss: 1.0529 - categorical_crossentropy: 1.0529 - acc: 0.7177
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "           Fuck you.
#
#                H"
#            Fuck you.
#                He can a was a bar and she don't a
#
# ----- diversity: 0.5
# ----- Generating with seed: "           Fuck you.
#
#                H"
#            Fuck you.
#
#                He like the sith the sas a cronger and she
#
# ----- diversity: 1.0
# ----- Generating with seed: "           Fuck you.
#
#                H"
#            Fuck you.
#
#                He all cr. Wels cor                                be Weaks
#
#                                            An the man, you rlom mes whatchin his
#                   on-get operspond the parmad twon's sheor... whand out far her
#                        for twat home ever.
#
#                                                  VINCENT
#                                Emele is beflo is ovey she frood. Go b
# Epoch 6/50
# 7614/7614 [==============================] - 6s 752us/step - loss: 1.0037 - categorical_crossentropy: 1.0037 - acc: 0.7299
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "oherent)
# "                        Who?
# oherent)
#                          Who?
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "oherent)
# "                        Who?
# oherent)
#                          Who?
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "oherent)
# "                        Who?
# oherent)
#                          Who?
#
#                                                – get wha baghiessed.
#
#                  ViRin' 'mmise is do you! But insenial if the quieene's sougnin' thiino him
#                         us cavanterspacess, shoke's extim9)
#                                                     YThus stepronglehehtnest of a
#                castersin' is at him doyichies. You'llags on one
#
# Epoch 7/50
# 7614/7614 [==============================] - 6s 816us/step - loss: 0.9642 - categorical_crossentropy: 0.9642 - acc: 0.7386
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "abienne SCREAMS and backs into a corner,"
# abienne SCREAMS and backs into a corner,
#
# ----- diversity: 0.5
# ----- Generating with seed: "abienne SCREAMS and backs into a corner,"
# abienne SCREAMS and backs into a corner,
#
# ----- diversity: 1.0
# ----- Generating with seed: "abienne SCREAMS and backs into a corner,"
# abienne SCREAMS and backs into a corner,
#                                   Zeget, snemer your)
#                      aigen purzeryelming into the mase fice. IN
#                Fabiennelp from that truese, cheriescar.
#
#                            sime now a butterough Winkere's 'aker.
#
#                                              JULES
#                                  anifs ain't bock ap in on the finnom in ellayiaroutterlaty-tient
# Epoch 8/50
# 7614/7614 [==============================] - 6s 812us/step - loss: 0.9271 - categorical_crossentropy: 0.9271 - acc: 0.7468
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "        I seriously doubt that.
#
#      "
#         I seriously doubt that.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "        I seriously doubt that.
#
#      "
#         I seriously doubt that.
#
#                     that the with the morame that through to
#                the shope of the same – but the finds the
#                                    you need my shote think you're
#                          the math the stortion to the been and
#                          that ass the was the whot the wat tho breaks
#                          through the with the wall be finds the wat
#
# ----- diversity: 1.0
# ----- Generating with seed: "        I seriously doubt that.
#
#      "
#         I seriously doubt that.
#
#                     arsmand doys the ot bit is I moundll strettion
#                the restord through bard.
#
#           raytingswith shosm popse "The Gimolw, Anyone wain's froe beshes handing the
#                Strise that.
#
#                     diened, I hand hake.
#
#
#    stambs and shat the waytlong stark, roob. Thin my thinging the raugle trinks abouex, it. Whack in
#
# Epoch 9/50
# 7614/7614 [==============================] - 7s 859us/step - loss: 0.8960 - categorical_crossentropy: 0.8960 - acc: 0.7540
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "                       every time: never"
#                        every time: never and she takes a but of the talking to the toller of the table to the talking to the really say to the toller to the car on the talking to the car to the streation.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "                       every time: never"
#                        every time: never deady looks up and sheady to chaired to closed to to the fuck are to the door.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "                       every time: never"
#                        every time: never two surfing to the body on theuty and has into to the a
#                                           VINCENT
#                                 VINCENT
#                                           Whis an ador.
#
#                    twere infiem to the twoutch.  Whear they killace, a petting up bluager out ewat if this
#                          Sugers eal. Talks your just glause
#
# Epoch 10/50
# 7614/7614 [==============================] - 6s 757us/step - loss: 0.8759 - categorical_crossentropy: 0.8759 - acc: 0.7591
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "g Man
#                continues in a lo"
# g Man
#                continues in a look of the fingers his hands to him.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "g Man
#                continues in a lo"
# g Man
#                continues in a losk her helf a head and
#
# ----- diversity: 1.0
# ----- Generating with seed: "g Man
#                continues in a lo"
# g Man
#                continues in a lome in a fucn, we
#                the tables, Kloody, three hour now, J'mmie" haods on the room, noghing a for it?
#
#             If you take Macall" Wame brinding boy:
#             YOUNG WOMAN
#                                         But whike he stills Muling roided, move on air Maynard'roun I'm to hak, 'em it they niggert to
#                          darying a gestubb.
#
#                 the
# Epoch 11/50
# 7614/7614 [==============================] - 6s 812us/step - loss: 0.8534 - categorical_crossentropy: 0.8534 - acc: 0.7641
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "                fifteen minutes before J"
#                 fifteen minutes before Jimmie's and
#
# ----- diversity: 0.5
# ----- Generating with seed: "                fifteen minutes before J"
#                 fifteen minutes before Jicesent of a rip of your
#
# ----- diversity: 1.0
# ----- Generating with seed: "                fifteen minutes before J"
#                 fifteen minutes before Jody's shoor are and
#                                    out the spot manutgy.
#
#                                          VINCENT
#                                    VINCENT
#                          (pun in the hand, Jules
#                                              I was a ghin's in through cruzzeat and / stills potie?
#
#                                Fith his dustins the wall of Jolis
#
# Epoch 12/50
# 7614/7614 [==============================] - 6s 842us/step - loss: 0.8341 - categorical_crossentropy: 0.8341 - acc: 0.7685
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "                  Clear? One...
#
#      "
#                   Clear? One...
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "                  Clear? One...
#
#      "
#                   Clear? One...
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "                  Clear? One...
#
#      "
#                   Clear? One...
#
#                                              LANCE
#                          What was they vely back, we're a fuck
#                                        Jules up Encles."TLI 2SHOPKY him, her being his
#                                         Yes wry, got think you tolker for mys,
#                          corn.
#
#                                      YOUNG MAN
#                               anemon
# Epoch 13/50
# 7614/7614 [==============================] - 6s 827us/step - loss: 0.8207 - categorical_crossentropy: 0.8207 - acc: 0.7726
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "                      MARSELLUS (O.S.)
# "
#                       MARSELLUS (O.S.)
#                          I want to the case a fivery in the backseat
#
# ----- diversity: 0.5
# ----- Generating with seed: "                      MARSELLUS (O.S.)
# "
#                       MARSELLUS (O.S.)
#                          Marsellus to the letter and into the
#                          me a ciffeat in the briefcase.
#
#                                                                                                                                                                                                              VINCENT
#                                                  VINCENT
#
# ----- diversity: 1.0
# ----- Generating with seed: "                      MARSELLUS (O.S.)
# "
#                       MARSELLUS (O.S.)
#                          You can tows.
#
#                WINT. .3.
#
#                does to it, Vincent sid is. The
#                          "yes it a buncons.f ass chred.
#
#                Did it ourtilaust bearDamfil!
#
#                                      Spritging, starts proble-thing beot at
#                          for a worries detwines a fiftracts. On.
#
#                gonna tellure
# Epoch 14/50
# 7614/7614 [==============================] - 6s 847us/step - loss: 0.8047 - categorical_crossentropy: 0.8047 - acc: 0.7756
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "nd LUCKY LADIES in
#                fanc"
# nd LUCKY LADIES in
#                fancent and Marsellus Well the bathroom and
#                          the fingers his head of the fillst of the bathroom with a trophing to
#                          the fingers to the finder hand to all the find his hands of the finds of the first the room.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "nd LUCKY LADIES in
#                fanc"
# nd LUCKY LADIES in
#                fance to his faster poother, waitred,
#                          that. It's to see it, it's see it a bathroom to
#                          the kit the pool.
#
#                                    want that gonna look die that the fuck the past of the bathroom. Then
#                          pooking the same to say the fight and starts to
#                          for the want to the fuck the bathroo
# ----- diversity: 1.0
# ----- Generating with seed: "nd LUCKY LADIES in
#                fanc"
# nd LUCKY LADIES in
#                fance is to the Quncake, ther aim?"
#
#                                    mean'thand's doop what the nood wishes.
#
#                Heppens, Zipp. Trung of his fuck up a
#                          are that gonease's of a Quized.
#
#                                      APREACLIAN
#                          You knooks from there fromine.
#
#             in iss heak. BREABS bothers not tonuid the Hit-offec
# Epoch 15/50
# 7614/7614 [==============================] - 6s 851us/step - loss: 0.7922 - categorical_crossentropy: 0.7922 - acc: 0.7785
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: " humor about that
#                     "
#  humor about that
#
# ----- diversity: 0.5
# ----- Generating with seed: " humor about that
#                     "
#  humor about that
#                                                                                                                                                                                                                                                                                                                                                                                                   money remand what the bedready and
# ----- diversity: 1.0
# ----- Generating with seed: " humor about that
#                     "
#  humor about that
#                          distains did room.
#
#                                    That's ever – something as outall,
#                                    What lit outcalneys is into the other to mpk-Cak, cheps a gannter or meda in
#                          Thanker, you're jush we have ass dingo mode
#                Everyelfos ensideg of Jimmie's fucked,
#                          dogeding from about it!
#
#
# Epoch 16/50
# 7614/7614 [==============================] - 6s 774us/step - loss: 0.7800 - categorical_crossentropy: 0.7800 - acc: 0.7820
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "
#                          Ezekiel 25:17"
#
#                          Ezekiel 25:17.." It's
#
# ----- diversity: 0.5
# ----- Generating with seed: "
#                          Ezekiel 25:17"
#
#                          Ezekiel 25:17.."
#
#                                         JULES
#                          I was say what hell that gonna me was
#                                                                                                                                                                                                                                 BUTCH
#                          Don't little back is a ma
# ----- diversity: 1.0
# ----- Generating with seed: "
#                          Ezekiel 25:17"
#
#                          Ezekiel 25:17--1-5YOROUILDING INGSON
#                She kif a sig to edning just sexy somedrondyes on Mhaie Hon reossause ho sure's med wead the bathrom.
#
#                Mia nigcent of she room ron by a meply broe
#                Vincent, nod nexty problem. The two a back wieen
#                          siteaps two his
#                          monfists. This pusiness ome here. I just is you cear. Red yo
# Epoch 17/50
# 7614/7614 [==============================] - 8s 1ms/step - loss: 0.7688 - categorical_crossentropy: 0.7688 - acc: 0.7839
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "               THE WOLF
#                "
#                THE WOLF
#                          I'm gonna be a tighting the
#
# ----- diversity: 0.5
# ----- Generating with seed: "               THE WOLF
#                "
#                THE WOLF
#                          Brett. He still don't did you get
#                                                                                                                                                                                 MIA
#                          What's in that fuckin' first the bathroom
#                                        SPEEDR (MOVING) – DAY
#
#                The Gimp is still bot on
# ----- diversity: 1.0
# ----- Generating with seed: "               THE WOLF
#                "
#                THE WOLF
#                        Fabiennible)
#                          – I ain't as the Gimp, he let
#                          it's night, you standing to be on bed
#                him.
#
#                Bus that dides hoppring readly srefforr, the
#                          fine?." It's "Walf hat there like a shit
#                          money sayin' this ill? INT. REENTSET – DAY
#
#                GEAY TOVAY ainne
# Epoch 18/50
# 7614/7614 [==============================] - 6s 788us/step - loss: 0.7588 - categorical_crossentropy: 0.7588 - acc: 0.7870
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "                    Nope.
#
#            "
#                     Nope.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "                    Nope.
#
#            "
#                     Nope.
#
#                                                                                                                                                                                                                              VINCENT
#                          Whatchen, I'll be with the chet me
#                          they get and you talking to hambard and
#                          seep you guy have a memort.
# ----- diversity: 1.0
# ----- Generating with seed: "                    Nope.
#
#            "
#                     Nope.
#
#                                    FABIENNE
#                          FABIENNE
#                          Both mes are but what I'm shird get abound
#                          flith.
#
#                                                      Uh, handin' hide tims is this boyman,
#                          deal.
#
#                            Busnt're and you take the gun henures
#                Ppenside a table?
# Epoch 19/50
# 7614/7614 [==============================] - 6s 790us/step - loss: 0.7507 - categorical_crossentropy: 0.7507 - acc: 0.7891
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "          – I'm talkin'. Now let me ask "
#           – I'm talkin'. Now let me ask you
#                          a vicior looks at her head the shot's
#                          looking at her head out of his hand the
#                          from the cornerstand the car and stands
#                          the should be fuckin' dook it, the strag starts the
#                          on the should be country one should
#                          the should be fuckin' dooks
# ----- diversity: 0.5
# ----- Generating with seed: "          – I'm talkin'. Now let me ask "
#           – I'm talkin'. Now let me ask you
#                          shit I couldn't shit. I'm not it's the
#                          friend smilling the wall to a bunce.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "          – I'm talkin'. Now let me ask "
#           – I'm talkin'. Now let me ask you go of on,
#                          question.
#
#                                                                            car.
#
#                                        JULES
#                          Did in again, Aumatse on a with
#                          use appears about the cart doxarlecs out
#                          'mour for like he does a coffee
#                cumf'romounts th
# Epoch 20/50
# 7614/7614 [==============================] - 6s 768us/step - loss: 0.7415 - categorical_crossentropy: 0.7415 - acc: 0.7912
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "a credit card based on
#                "
# a credit card based on
#
# ----- diversity: 0.5
# ----- Generating with seed: "a credit card based on
#                "
# a credit card based on
#                                                            JULES
#                          I wanna know I the wall you know I was she know
#                                                                                                                                                                                                 VINCENT
#                          What does not and that was a should be
#
# ----- diversity: 1.0
# ----- Generating with seed: "a credit card based on
#                "
# a credit card based on
#                starts twentical alver Jules and gettly sian it.
#
#                                        LANCE
#                          Frundree!!
#
#                                            BUTCH
#                          But we we knee wath Ut's go enterver set
#                          peeple and he hands her a wall my fast.
#                She's fel the BOSSS I hen a BREAM., he takes
#
# Epoch 21/50
# 7614/7614 [==============================] - 6s 772us/step - loss: 0.7340 - categorical_crossentropy: 0.7340 - acc: 0.7932
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: " you.
#
#                                "
#  you.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " you.
#
#                                "
#  you.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " you.
#
#                                "
#  you.
#
#                                    Well,
#                                               – abilongh, smartly bary a tounting to
#                cunco two Lenty has nameth ist to it, Maynard smoke in
#                          race had driving Jimnie poulds tumning.
#
#                                              Fabienne still Collady with DaviN
#                          pessing the watch stairs right nigger, trust atrougt and
# Epoch 22/50
# 7614/7614 [==============================] - 7s 929us/step - loss: 0.7270 - categorical_crossentropy: 0.7270 - acc: 0.7956
#
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: "                   omelet, next minute s"
#                    omelet, next minute shit us a long mement
#
# ----- diversity: 0.5
# ----- Generating with seed: "                   omelet, next minute s"
#                    omelet, next minute stick up the window.
#
#                                                              That one is the corner it, Marsellus reading on the talkin' tobator and you
#                          on my car through the show the corner to
#                          of your gonna do... all through the street.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "                   omelet, next minute s"
#                    omelet, next minute shit will hear bedratel"
#                          goom, his me?
#
#                                              VINCENT
#                          coclush of thoughts herd a down in the out through to a
#                          poure, but that will, guys. INT. BLAYN RAD then stompying of here? You
#                          a know you in a casure you me in from as think in
#
# Epoch 23/50
# 7614/7614 [==============================] - 6s 784us/step - loss: 0.7206 - categorical_crossentropy: 0.7206 - acc: 0.7966
#
# ----- Generating text after Epoch: 22
# ----- diversity: 0.2
# ----- Generating with seed: "arilyn Monroe...
#
#                Then,"
# arilyn Monroe...
#
#                Then, stands in the counter is she continues to
#                          the boy.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "arilyn Monroe...
#
#                Then,"
# arilyn Monroe...
#
#                Then, the band-of and sparides his head: "yes."
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "arilyn Monroe...
#
#                Then,"
# arilyn Monroe...
#
#                Then, and STAET STAKE APALLACE'S kATCEED in the kicking her, as ZEDGLODLY LOVES Jody.
#                                           It's aow: I need, that!
#
#                                        MIA'S TEVA
#                          Well you oth this in there I get ma fuckin'
#                          somethin'?
#
#                MAR VINCENT THERSher breaker a nobver sew
#                COUTH a Ming
# Epoch 24/50
# 7614/7614 [==============================] - 6s 808us/step - loss: 0.7146 - categorical_crossentropy: 0.7146 - acc: 0.7987
#
# ----- Generating text after Epoch: 23
# ----- diversity: 0.2
# ----- Generating with seed: "s.
#
#                                   "
# s.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "s.
#
#                                   "
# s.
#
#                                                                                                                              VINCENT
#                          One doin' it to diffeers do you tell you
#                          between thing with the still.
#
#                                      VINCENT
#                          No, no, no, no, no, no, no, no, no, no, no, not. It's
#                          his boy.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "s.
#
#                                   "
# s.
#
#                                      Bynat man sever.
#
#                Just beessesty smokes on the car, humbs, faving reomet. We
#                          shit yearion in the givivar opens are in the big Tanne watch on
#                          in away. Are?
#
#                Fabienne starts talking to the watch leave
#                          just you're says:  The Yound Wighllen in
#                                      CUT
# Epoch 25/50
# 7614/7614 [==============================] - 6s 785us/step - loss: 0.7094 - categorical_crossentropy: 0.7094 - acc: 0.7997
#
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: "              me rememberin' have just b"
#               me rememberin' have just beed straight
#                          the back from the back and door bedroom in the back and
#
# ----- diversity: 0.5
# ----- Generating with seed: "              me rememberin' have just b"
#               me rememberin' have just briefcase
#                                          VINCENT
#                          What ain't gonna give to your fuckin'
#                          but there's the alley?
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "              me rememberin' have just b"
#               me rememberin' have just brow the
#                lease OY-UNGLD in a watch precty tearly greatu Lith a
#                through build still a grob to poination of a racisy poser)
#                          Corrain?  Candy inser an hearbied for his drag is falled toward
#                         gootha hake down through one: 1972. BUTCHY
#                FADE TO BOT, on the back Breters to he want to be onded,
#
# Epoch 26/50
# 7614/7614 [==============================] - 6s 776us/step - loss: 0.7033 - categorical_crossentropy: 0.7033 - acc: 0.8012
#
# ----- Generating text after Epoch: 25
# ----- diversity: 0.2
# ----- Generating with seed: "                                 VINCENT"
#                                  VINCENT
#                          What does the shot the shot the show
#                          the shot.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "                                 VINCENT"
#                                  VINCENT
#                          Where you the fight.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "                                 VINCENT"
#                                  VINCENT
#                          Don't you so tellin'?
#
#                                              MAYNARD
#                          Shil by the Ther except of "49.  He hangs up the gun in
#                          unyphine we exieple doin' hast
#                the profictes.
#
#                Vincent and ROOMES the door a boll goddamn
#                          have sigster did it.
#
#
# Epoch 27/50
# 7614/7614 [==============================] - 6s 829us/step - loss: 0.7001 - categorical_crossentropy: 0.7001 - acc: 0.8019
#
# ----- Generating text after Epoch: 26
# ----- diversity: 0.2
# ----- Generating with seed: " deal was she
#                         "
#  deal was she
#                          and she lays in the back and she been see
#                          the same shit fill a cleat and go
#                          problems, I got a wallets the street, but
#                          was that way to strike with the pointing the
#                          the patherfucker what I'm gonna be
#                          for a say.  An her head the bathroom shot.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " deal was she
#                         "
#  deal was she
#                          he does in the other playe. Ginnt
#                          for as that watch we got a court
#                          from the first talking all warts the shot.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " deal was she
#                         "
#  deal was she
#                          he cashet stickless?
#
#                                         VINCENT
#                               (on the back reowdles.
#
# ...
# ----- diversity: 1.0
# ----- Generating with seed: "teaming hot cup of coffee out of a
#    "
# teaming hot cup of coffee out of a
#                the leash.
#
#                She sellee days are fears. The need exasus
#                          there's My any, you're ilver on
#                but I meand here and tell you went
#                the rush pieces down her here.
#
#                                      pell.
#
#                                      JODY (O.S.)
#                          Yeah.
#
#
# Epoch 41/50
# 7614/7614 [==============================] - 6s 804us/step - loss: 0.6559 - categorical_crossentropy: 0.6559 - acc: 0.8138
#
# ----- Generating text after Epoch: 40
# ----- diversity: 0.2
# ----- Generating with seed: "        bloodiest and, hands-down, the m"
#         bloodiest and, hands-down, the moment
#                          the strain. I'm not is it?
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "        bloodiest and, hands-down, the m"
#         bloodiest and, hands-down, the moter on
#                          behind the bedroom with the car that
#                          on the bathroom. That's all your carled
#                          situation.
#
#                                                     MIA
#                          I don't have massage?
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "        bloodiest and, hands-down, the m"
#         bloodiest and, hands-down, the moment Esmareld by
#                When you is it?
#
#                                                  VINCENT
#                          Cool.  What, you ass bed.
#
#                                               VINCENT
#                          Whaddya ountifically shot. Not got that
#                          but say we Aftat a dats mouths, bad
#                intention.
#
#
# Epoch 42/50
# 7614/7614 [==============================] - 8s 1ms/step - loss: 0.6521 - categorical_crossentropy: 0.6521 - acc: 0.8144
#
# ----- Generating text after Epoch: 41
# ----- diversity: 0.2
# ----- Generating with seed: "                                        "
#
# ----- diversity: 0.5
# ----- Generating with seed: "                                        "
#                                                                                              VINCENT
#                          Every his assed the night of the door of the
#                her one it an accest of his pause)
#                          I need a masally ard a nam of heroy.
#
#                Then her cener tonter.
#
#                                               BUTCH
#                          Which on' know of as if I think
# ----- diversity: 1.0
# ----- Generating with seed: "                                        "
#                                          MARSELLUS
#                          I think had nits car and Lance, acher see redrown once, hand has words off.
#
#                                             VINCENT
#                          Then I can me.  'm her head but have as worth through to them higs Checeple?
#
#                                                VINCENT
#                          I'm not a hard.
#
#                EXT. BUTKY-
# Epoch 43/50
# 7614/7614 [==============================] - 6s 769us/step - loss: 0.6509 - categorical_crossentropy: 0.6509 - acc: 0.8151
#
# ----- Generating text after Epoch: 42
# ----- diversity: 0.2
# ----- Generating with seed: "like?
#
#                                "
# like?
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "like?
#
#                                "
# like?
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "like?
#
#                                "
# like?
#
#                                      FABIENNE
#                          Bretty smoke, some man. I just
#                          situatin' it stosituen chicka-givl
#                          ya 2.. The is all find on a
#                          which is not mad, bat as expect us a vincant,
#                          that sets somethen by thee way the straking:
#                Mia cool the inside. The Wollace, FABING Zed go,
# Epoch 44/50
# 7614/7614 [==============================] - 7s 864us/step - loss: 0.6488 - categorical_crossentropy: 0.6488 - acc: 0.8153
#
# ----- Generating text after Epoch: 43
# ----- diversity: 0.2
# ----- Generating with seed: "Butch quickly takes measure of the situa"
# Butch quickly takes measure of the situation. Normils the
#                          the straight at the first talk a big sig of
#                          the fuckin' shit fill 'em a styray I
#
# ----- diversity: 0.5
# ----- Generating with seed: "Butch quickly takes measure of the situa"
# Butch quickly takes measure of the situation.
#
#                                                                                                                                                                                                         LANCE
#                                      BUTCH
#
# ----- diversity: 1.0
# ----- Generating with seed: "Butch quickly takes measure of the situa"
# Butch quickly takes measure of the situation. The
#                Quither injoympat.
#
#                                            MAYNARD
#                          Lenfa libutrendin' a passages, studs fare
#                          bloodercalts Butch, pieling on the acter, doorway.
#
#                                         VINCENT
#                          Way?
#
#                                         ADINENTINIE
#
# Epoch 45/50
# 7614/7614 [==============================] - 5s 718us/step - loss: 0.6461 - categorical_crossentropy: 0.6461 - acc: 0.8163
#
# ----- Generating text after Epoch: 44
# ----- diversity: 0.2
# ----- Generating with seed: "h fox' specialty
#                      "
# h fox' specialty
#                          the same thing to a take out of the
#                          a fact you gotta get's comes on it.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "h fox' specialty
#                      "
# h fox' specialty
#                          you got about the fingens down, as if
#                          a foot massage of an injection.
#
#                                                                                                                                                                                                                                                                          JULES
#
# ----- diversity: 1.0
# ----- Generating with seed: "h fox' specialty
#                      "
# h fox' specialty
#                          coild works, forget it?
#
#                Butch COTSS another.
#
#                Vincent'd Vincent and Juxpzibenzell ZEDES.
#
#                INT. VINCENT SPEED" ROOM) – NIGHT
#
#                CAPPON UP AGEM – NIGHT
#
#                                    That's like the spet, that to a turacts and planes up to the close time. Butch back at him. Oe is
#                          fuckin' darean.
# Epoch 46/50
# 7614/7614 [==============================] - 5s 718us/step - loss: 0.6452 - categorical_crossentropy: 0.6452 - acc: 0.8166
#
# ----- Generating text after Epoch: 45
# ----- diversity: 0.2
# ----- Generating with seed: " the case.
#
#                Like a ratt"
#  the case.
#
#                Like a ratters)
#                               (over the bally of the car leaves and
#
# ----- diversity: 0.5
# ----- Generating with seed: " the case.
#
#                Like a ratt"
#  the case.
#
#                Like a ratts hand, then she Bught Dave out of
#
# ----- diversity: 1.0
# ----- Generating with seed: " the case.
#
#                Like a ratt"
#  the case.
#
#                Like a ratters)
#                          A right now.  Zed means the floom townate
#                          caught at "ye.!. The PORROKE. op. The Gird grip!
#                               (hutings out is a bunnard Vincent, than I take
#                          want to the laugh.
#
#                Butch.
#
#                INT. LANCE'S HOUSE (ILAININGN, SIX'S they countinalitting persent, ain't your gonna
# Epoch 47/50
# 7614/7614 [==============================] - 7s 876us/step - loss: 0.6436 - categorical_crossentropy: 0.6436 - acc: 0.8169
#
# ----- Generating text after Epoch: 46
# ----- diversity: 0.2
# ----- Generating with seed: "ch other, it'll
#                       "
# ch other, it'll
#                          the first two are the bathroom. We see
#                          on the shot.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ch other, it'll
#                       "
# ch other, it'll
#                          through the fucks a look differry, who would
#                                                                                                                                                                                                                                                          VINCENT
#                          What's your and a fuckin' Marsellus
#                          the
# ----- diversity: 1.0
# ----- Generating with seed: "ch other, it'll
#                       "
# ch other, it'll
#                          bit they're on the mortionalf on
#                her is interes to crecturred. Birry
#                          Jules, we're given hadda guns
#                          the interical?
#
#                                   INT. CHERE) STOPPED / RILLIDING him our a deaver so
#                          pooking with a the cartainful your
#                          the endly me belly.
#
#
# Epoch 48/50
# 7614/7614 [==============================] - 6s 803us/step - loss: 0.6416 - categorical_crossentropy: 0.6416 - acc: 0.8180
#
# ----- Generating text after Epoch: 47
# ----- diversity: 0.2
# ----- Generating with seed: "a what, you give me one of
#            "
# a what, you give me one of
#                          that fuckin' shot!
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "a what, you give me one of
#            "
# a what, you give me one of
#                          me an' you.
#
#                                                                                                                             BUTCH
#                          Floods as it man, you so there's a fuckin'
#                          this is a fuckin' parts this is that his
#                          windows at the black could blowically
#                          you not me!
# ----- diversity: 1.0
# ----- Generating with seed: "a what, you give me one of
#            "
# a what, you give me one of
#                          even you, I can't go?
#
#                                                VINCENT
#                          We're
#                          fuckin' someth. It's out of a "Edoe've
#                          your please. If all thatPordagin' that –
#
#                                               VINCENT
#                          It's that I mested thot's go in my
#
# Epoch 49/50
# 7614/7614 [==============================] - 7s 875us/step - loss: 0.6411 - categorical_crossentropy: 0.6411 - acc: 0.8175
#
# ----- Generating text after Epoch: 48
# ----- diversity: 0.2
# ----- Generating with seed: " gimmick where every
#                  "
#  gimmick where every
#                          what I'm gonna do that?
#
#                                      JULES
#                          What the same ball at the shot's gotter
#                          the same fuckin' studies his to know
#                          as if a means as there one shit is the same fings
#                          you got me that I get a know, I had
#                          the same fuckin' disposs
# ----- diversity: 0.5
# ----- Generating with seed: " gimmick where every
#                  "
#  gimmick where every
#                          like a madman, you're gonna be a
#                          there wife is the same flat her exause yellus
#                          pie.
#
#                                      JULES
#                          This is the way around the sticking a clies is on the other with the somether the showe from his
#                          man, I got me, I want to kill ya what house
#
# ----- diversity: 1.0
# ----- Generating with seed: " gimmick where every
#                  "
#  gimmick where every
#                          the Avarammer?

# %% [markdown]
# > **Ex. 5.1.2**: Add a callback for Tensorboard, so you can log the training process. Start training the network (takes ~10 minutes on my computer). While it's running move on to the next question.

# %% [markdown]
# > **Ex. 5.1.3**: Answer the questions in the code above (look for code comments starting with `Q:`).

# %% [markdown]
# > **Ex. 5.1.4**: Did the network finish training? Consider the generated text across epochs.
# 1. In the early batches (0-10), the generated text looks very bad. Can you explain why the low diversity generated text contains almost only the symbol " " (that is, spaces)?
# 2. The high diversity generated text is messed up too, but in a different way. Explain how.
# 3. In later batches (20-30) what do you notice is off about the low diversity generated text?

# %% [markdown]
# > **Ex. 5.1.5**: For the network trained over all 50 epochs, generate a longer piece of text
# (say 5000 symbols long). Use the sentence `text[1486:1526]` as seed (starts with 'YOUNG MAN' ends with 'No, ')
# and set diversity to 0.5.
# Describe what features of the screenplay and language in general that the network learned in only 50 epochs.
# Also describe what serious mistakes it makes.

# %% [markdown]
# > **Ex. 5.1.6**: Do the same as above, but for 40 random letters (e.g. smash away on your keyboard) as seed. What happens? Can you explain why?

# %% [markdown]
# > **Challenge** Download [this](https://www.yelp.com/dataset/download) Yelp dataset and train a model that predicts rating given a review text!
