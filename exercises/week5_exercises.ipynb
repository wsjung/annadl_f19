# %% [markdown]
# > **DO NOT EDIT IF INSIDE annadl_f19 folder**

# %% [markdown]
# # Week 5: Recurrent neural networks
#
# Text, speech, weather, sensor output and video are but a few examples of the many types of data that is inherently sequential. So how does one predict the next word in a sentence, future temperatures or missing video frames? Using **recurrent neural networks** (RNNs)!

# %%
# %matplotlib inline
# %load_ext tensorboard

import numpy as np
import requests as rq
import random
import sys
import io
from bs4 import BeautifulSoup
import keras
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, LSTM
from keras.optimizers import RMSprop
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# ## Exercises

# %% [markdown]
# #### Modeling text

# %% [markdown]
# Text prediction is a good place to start when learning about RNNs, because most of us humans have a pretty well
# optimized inner model for text prediction ourselves. We can, therefore, easily assess the performance of a neural
# network in executing this task.
#
# Below is some code that loads the screenplay for Tarantino's 1994 film 'Pulp Fiction'. I recommend reading through the
# first 20 lines or so to get a feeling for the language and style used (and enjoy probably the best written screenplay
# in the history of film).

# %%
response = rq.get("http://www.dailyscript.com/scripts/pulp_fiction.html")
text = BeautifulSoup(response.content, "html.parser").getText()
print(text[:2000])
# Out:
# "PULP FICTION" -- by Quentin Tarantino & Roger Avary
#
#
#                                       "PULP FICTION"
#
#                                             By
#
#                              Quentin Tarantino & Roger Avary
#
#
#
#                PULP [pulp] n.
#
#                1. A soft, moist, shapeless mass or matter.
#
#                2. A magazine or book containing lurid subject matter and
#                being characteristically printed on rough, unfinished paper.
#
#                American Heritage Dictionary: New College Edition
#
#                INT. COFFEE SHOP – MORNING
#
#                A normal Denny's, Spires-like coffee shop in Los Angeles.
#                It's about 9:00 in the morning. While the place isn't jammed,
#                there's a healthy number of people drinking coffee, munching
#                on bacon and eating eggs.
#
#                Two of these people are a YOUNG MAN and a YOUNG WOMAN. The
#                Young Man has a slight working-class English accent and,
#                like his fellow countryman, smokes cigarettes like they're
#                going out of style.
#
#                It is impossible to tell where the Young Woman is from or
#                how old she is; everything she does contradicts something
#                she did. The boy and girl sit in a booth. Their dialogue is
#                to be said in a rapid pace "HIS GIRL FRIDAY" fashion.
#
#                                      YOUNG MAN
#                          No, forget it, it's too risky. I'm
#                          through doin' that shit.
#
#                                      YOUNG WOMAN
#                          You always say that, the same thing
#                          every time: never again, I'm through,
#                          too dangerous.
#
#                                      YOUNG MAN
#                          I know that's what I always say. I'm
#                          always right too, but –

# %% [markdown]
# > **Ex. 5.1.1:** What is the most used symbol in this screenplay and what accuracy would a model constantly predicting this symbol obtain? In other words, what is the "baseline accuracy"?

# %%
char_freqs = {}

for symbol in text:
    if symbol in char_freqs:
        char_freqs[symbol] += 1
    else:
        char_freqs[symbol] = 1

freqs = 0       
i=0
max_freq = 0
        
for symbol in sorted(char_freqs, key=char_freqs.get, reverse=True):
    freqs += char_freqs[symbol]
    if i==0:
        print("max freq letter: %s with %d occurences" % (repr(symbol), char_freqs[symbol]))
        max_freqs = freqs
    i+=1
    
acc = max_freqs / freqs
print("baseline accuracy: %f" % acc)
# Out:
# max freq letter: ' ' with 164787 occurences
# baseline accuracy: 0.541059

# %% [markdown]
# I've adapted some code for text generation from [this Keras example](https://keras.io/examples/lstm_text_generation/).
# I've inserted some questions in the code (look for `Q:`) for you to answer in the exercise below.

# %%
# Q1: What is the purpose of this block? When is `char_indices` used? What about `indices_char`?
# A1: char_indices is a dictionary of the characters keyed by the characters and indices_char is keyed by the indices
chars = sorted(list(set(text)))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# Q2: What is the purpose of this block? What does the `seqlen` and `step` parameters do?
# A2: seqlen specifies the length of the sequence for each iteration and the step parameter specifies the number of elements to skip
seqlen = 40
step = seqlen
sentences = []
for i in range(0, len(text) - seqlen - 1, step):
    sentences.append(text[i: i + seqlen + 1])

# Q3: What about this block? What is `x` and what is `y`? Why do they have this dimensionality?
# A3: `x` is the current character and `y` is the next character
x = np.zeros((len(sentences), seqlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), seqlen, len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    # Q3a: What happens in this loop?
    # A3a: assigns 1 to the current char and the next char
    for t, (char_in, char_out) in enumerate(zip(sentence[:-1], sentence[1:])):
        x[i, t, char_indices[char_in]] = 1
        y[i, t, char_indices[char_out]] = 1


# Q4: Here we build the model. What does the `return_sequences` argument do? Why the dense layer at the end?
# A4: returns the full output sequence
model = Sequential()
model.add(LSTM(128, input_shape=(seqlen, len(chars)), return_sequences=True))
model.add(Dense(len(chars), activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer=RMSprop(lr=0.01),
    metrics=['categorical_crossentropy', 'accuracy']
)

def sample(preds, temperature=1.0):
    """Helper function to sample an index from a probability array."""
    preds = np.asarray(preds).astype('float64')
    preds = np.exp(np.log(preds) / temperature)  # softmax
    preds = preds / np.sum(preds)                #
    probas = np.random.multinomial(1, preds, 1)  # sample index
    return np.argmax(probas)                     #


def on_epoch_end(epoch, _):
    """Function invoked at end of each epoch. Prints generated text."""
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - seqlen - 1)
    
    # Q5: What does diversity do?
    # A5: picks a float in the list to divide the predictions by to give chance for possible local minima escape
    for diversity in [0.2, 0.5, 1.0]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + seqlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, seqlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.
            
            # What is the dimensionality of `preds`? Why do we input `preds[0, -1]` to the `sample` function?
            preds = model.predict(x_pred, verbose=0)
            next_index = sample(preds[0, -1], diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)
# Out:
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-7fd6d32884a6> in <module>
#      84           batch_size=128,
#      85           epochs=50,
# ---> 86           callbacks=[print_callback])
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2669                                 feed_symbols,
#    2670                                 symbol_vals,
# -> 2671                                 session)
#    2672         if self.run_metadata:
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#
# ~/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py in _make_callable(self, feed_arrays, feed_symbols, symbol_vals, session)
#    2621             callable_opts.run_options.CopyFrom(self.run_options)
#    2622         # Create callable.
# -> 2623         callable_fn = session._make_callable_from_options(callable_opts)
#    2624         # Cache parameters corresponding to the generated callable, so that
#    2625         # we can detect future mismatches and refresh the callable.
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _make_callable_from_options(self, callable_options)
#    1487     """
#    1488     self._extend_graph()
# -> 1489     return BaseSession._Callable(self, callable_options)
#    1490
#    1491
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in __init__(self, session, callable_options)
#    1444       try:
#    1445         self._handle = tf_session.TF_SessionMakeCallable(
# -> 1446             session._session, options_ptr)
#    1447       finally:
#    1448         tf_session.TF_DeleteBuffer(options_ptr)
#
# KeyboardInterrupt:

# %%
from datetime import datetime

logdir = './logs_week5/' + datetime.now().strftime("%Y%m%d-%H%M%S") # log file name
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

# %%
model.fit(x, y,
          batch_size=128,
          epochs=50,
          callbacks=[print_callback, tensorboard_callback])
# Out:
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /home/wjung/anaconda3/lib/python3.7/site-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/50
# 7614/7614 [==============================] - 8s 1ms/step - loss: 2.1510 - categorical_crossentropy: 2.1510 - acc: 0.5492
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "      It's cool, Honey Bunny, we're stil"
#       It's cool, Honey Bunny, we're stils
# ----- diversity: 0.5
# ----- Generating with seed: "      It's cool, Honey Bunny, we're stil"
#       It's cool, Honey Bunny, we're stiltsor                                                                                                                                it
# ----- diversity: 1.0
# ----- Generating with seed: "      It's cool, Honey Bunny, we're stil"
# s     It's cool, Honey Bunny, we're stile mflclEilm whe porour anltsf hancaat  n
#
#             e       any
#      VIm  slA,
#        bweomhal,g toati  hans,a dafgher.
#    wvetc.
#
#               Min.
#
#
#     oungs
#
#     Fer
# ifonClaipb
#  asokarl.
#
#      –oHonsois an          INEE
# a                  opsangica
#
#           a d  n:da.t. g  , baS.
#
#    T cartdCi.
#
#      gEHT
#
#         ACTHE
#  DINT"EIG.
#
#    ounrann d
# Epoch 2/50
# 7614/7614 [==============================] - 6s 836us/step - loss: 1.4086 - categorical_crossentropy: 1.4086 - acc: 0.6357
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "t, but is stopped at the light on
#     "
# t, but is stopped at the light on
#
# ----- diversity: 0.5
# ----- Generating with seed: "t, but is stopped at the light on
#     "
# t, but is stopped at the light on
#
# ----- diversity: 1.0
# ----- Generating with seed: "t, but is stopped at the light on
#     "
# t, but is stopped at the light on
#                     Wath her If this gouba. o. on  thit's s kedRt th s a the CINCEER(MING SHEN)
#                                 Win in FNDESGARYou gdouas nat! yhald mauh  I'm butcein's tot he.
#
#                                             the tor, tho  hi's wtren a Sive cod.
#
#                                                      omet
#
# Epoch 3/50
# 7614/7614 [==============================] - 6s 806us/step - loss: 1.1998 - categorical_crossentropy: 1.1998 - acc: 0.6820
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "nybody.
#                Jules and Vince"
# nybody.
#                Jules and Vincent the sheres of the shores of the fores in the shot of the sheres and the sheres and the shout and and the sher in the shith the pares and the shomes in the shith the rooks and the shomes and the shat and the sher the shith the shot and and the finger the shist and a santer and the sheres on the sher and the sheres in the shith the shith the shing the shot and and the shith the shot the shing and
# ----- diversity: 0.5
# ----- Generating with seed: "nybody.
#                Jules and Vince"
# nybody.
#                Jules and Vincent on the the sheratse, whething the in the shing a limeseres on the sister hen a finteres in this the saster mand stath ther an whe's an his out a poing, me the the the with the sintast the
# ----- diversity: 1.0
# ----- Generating with seed: "nybody.
#                Jules and Vince"
# nybody.
#                Jules and Vincent. IT poneticksteso.
#
#                              (inte         PUPCaSS WOLULUS  OLULLLUST OUShingtneinly ither innonch?
#
#                  I thring wangd shear)
#                Goz, futhin, that?
#
#   S                       Laves in a mans belyatear cofbast im a carse antaplebsesstors?
#
#                               dith what. The po,s lutching bpetbemsingles the ligitget his iptistint af
# Epoch 4/50
# 7614/7614 [==============================] - 6s 781us/step - loss: 1.1015 - categorical_crossentropy: 1.1015 - acc: 0.7058
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "    The cab WHIPS out of the alley, FISH"
#     The cab WHIPS out of the alley, FISHENT in the back the but the reat the rook and the reather and
#
# ----- diversity: 0.5
# ----- Generating with seed: "    The cab WHIPS out of the alley, FISH"
#     The cab WHIPS out of the alley, FISHENT WOLF
#
# ----- diversity: 1.0
# ----- Generating with seed: "    The cab WHIPS out of the alley, FISH"
#     The cab WHIPS out of the alley, FISHERDAND
#                    YOUNG  sfing and, and yeu hever, nethen placseh kisty drederurtentseutanel the
#                       wine and hurdene, a dia med at his pomp. Vincent the has. wit the rakes"
#
#                      Butch the corps of the shat lake Cable weean.
#
#                          do.
#
#                the riture, pustlle?
#
#                              the hot a rus wish wcrop
# Epoch 5/50
# 7614/7614 [==============================] - 6s 776us/step - loss: 1.0393 - categorical_crossentropy: 1.0393 - acc: 0.7202
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "                                   JULES"
#                                    JULES
#
# ----- diversity: 0.5
# ----- Generating with seed: "                                   JULES"
#                                    JULES
#
# ----- diversity: 1.0
# ----- Generating with seed: "                                   JULES"
#                                    JULES
#
#                               VINCENT
#                                  S VINCENT
#                                             JULES
#                            Marse.
#
#                        YOXTFED HELDY UNGfomen it fobuving off.
#
#                       shauge topp.
#
#                         VINCENT
#                                               To him,
#
# Epoch 6/50
# 7614/7614 [==============================] - 6s 832us/step - loss: 0.9917 - categorical_crossentropy: 0.9917 - acc: 0.7324
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "                          VINCENT
#      "
#                           VINCENT
#
# ----- diversity: 0.5
# ----- Generating with seed: "                          VINCENT
#      "
#                           VINCENT
#
# ----- diversity: 1.0
# ----- Generating with seed: "                          VINCENT
#      "
#                           VINCENT
#                                   me netsemithiat of the books.S. Yee'r foclinago ala in
#                                          WOOPET HOO – TIILOM) (O.S.)
#                          FABIENNE
#                                                 YODDY MOVE SOOP (I. SIGLING HOUSEEN BREANSHOOCE – DO:
#
#
#                       the brow, )rain, lody can the but a teating
#
# Epoch 7/50
# 7614/7614 [==============================] - 6s 778us/step - loss: 0.9547 - categorical_crossentropy: 0.9547 - acc: 0.7418
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "         Quack, quack, quack, quack, qua"
#          Quack, quack, quack, quack, quack and
#
# ----- diversity: 0.5
# ----- Generating with seed: "         Quack, quack, quack, quack, qua"
#          Quack, quack, quack, quack, quacked a called,
#
# ----- diversity: 1.0
# ----- Generating with seed: "         Quack, quack, quack, quack, qua"
#          Quack, quack, quack, quack, quack to
#                        justioned the
#                                     Rourtlythe?
#
#                      JIMMIE
#                Hely cie
#                Vincent and MIA
#                     was sabken of got the blausc graden goorain" hean, rat
#                     leans of cound have back races on the leffems wown the
#           Vincent town camger for beget up tow foot
#
# Epoch 8/50
# 7614/7614 [==============================] - 6s 778us/step - loss: 0.9243 - categorical_crossentropy: 0.9243 - acc: 0.7491
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "                    do it or fucking die"
#                     do it or fucking die you the ream
#
# ----- diversity: 0.5
# ----- Generating with seed: "                    do it or fucking die"
#                     do it or fucking die my still
#
# ----- diversity: 1.0
# ----- Generating with seed: "                    do it or fucking die"
#                     do it or fucking die my Winsto grenks ip now,'al heard ar on
#                                          don a bricks rog, goadd and home and
#              The full acs he'plow, Hody. Ad er in m hamband cound
#                              Marsellus! It's any an' sut a with the
#                          INT. MARCELLUS' HOP un his mexinun.
#
#                      kitch's gay see walks one take Vince im it, and konkin
# Epoch 9/50
# 7614/7614 [==============================] - 6s 802us/step - loss: 0.8939 - categorical_crossentropy: 0.8939 - acc: 0.7556
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "of
#                cars in the street. "
# of
#                cars in the street. We're gonna be the shows and
#
# ----- diversity: 0.5
# ----- Generating with seed: "of
#                cars in the street. "
# of
#                cars in the street. Jimmie's they're
#
# ----- diversity: 1.0
# ----- Generating with seed: "of
#                cars in the street. "
# of
#                cars in the street. Woof metrice lease.
#
#                themparversandme buh showereldan want the did. Noithem's
#                                                                   BUTCH
#                               Esmends.
#
#      JALDY
#                               JULES
#                         How you'rl 'mat to tho! We're a beet goes then, and in one.
#
#                            to her be. It's ass biela
# Epoch 10/50
# 7614/7614 [==============================] - 7s 882us/step - loss: 0.8668 - categorical_crossentropy: 0.8668 - acc: 0.7612
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "     What time is it?
#
#                "
#      What time is it?
#
# ----- diversity: 0.5
# ----- Generating with seed: "     What time is it?
#
#                "
#      What time is it?
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "     What time is it?
#
#                "
#      What time is it?
#
#                whit do you tark.
#
#                a can gut andswas fuct I
#                                      Hangane as on the door, a coetm, hasht an'
#                              To Roside ain't not ne is done, but taking
#                                          BUTCH
#                          Mayvars haps man to to here.
#
#                               VINCENT
#                            "YOUNG MAN
# Epoch 11/50
# 7614/7614 [==============================] - 6s 769us/step - loss: 0.8467 - categorical_crossentropy: 0.8467 - acc: 0.7664
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "                     (with a smile)
#    "
#                      (with a smile)
#
# ----- diversity: 0.5
# ----- Generating with seed: "                     (with a smile)
#    "
#                      (with a smile)
#
# ----- diversity: 1.0
# ----- Generating with seed: "                     (with a smile)
#    "
#                      (with a smile)
#                          I don't kase I'm bout Waith no, out a suepairs.
#                          INT.  Fyour pice, and glean. OD  And Pumpkin
#                wish. I'm dulamires dillan. He back it
#                          I wanna no, Unxinuse been wemaned, house in Vincent
#                          You've know what you give a out, has it. Brungiound both we boin. But Klonaob and
#
# Epoch 12/50
# 7614/7614 [==============================] - 6s 764us/step - loss: 0.8301 - categorical_crossentropy: 0.8301 - acc: 0.7706
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "s,
#                and the icons are pl"
# s,
#                and the icons are places the show the back in the back to
#
# ----- diversity: 0.5
# ----- Generating with seed: "s,
#                and the icons are pl"
# s,
#                and the icons are place with a pance is
#
# ----- diversity: 1.0
# ----- Generating with seed: "s,
#                and the icons are pl"
# s,
#                and the icons are pleesen BLEES A WOLFWAR #1DONO?
#
#                                           Englides to sticks.
#
#                            lean is starlis't the Young Man on a
#                          he diss, I dreasing stails the Buthth?
#
#                                                                     I'm Jules?
#
#                fiftel – do you say in Am. Wa Butch
#                          he bas, c
# Epoch 13/50
# 7614/7614 [==============================] - 6s 765us/step - loss: 0.8136 - categorical_crossentropy: 0.8136 - acc: 0.7744
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "                    boxer vacate the rin"
#                     boxer vacate the ring out of the fuck
#
# ----- diversity: 0.5
# ----- Generating with seed: "                    boxer vacate the rin"
#                     boxer vacate the ring room to stop
#                          Fabienne reactly baby and Vincent and "CRASTING in
#                The front dean to the park door of the
#                          here side comp and speaks door for her
#                          Pumpkin and Vincent but I that inters a stoker
#                          Fabienne with the find of the boxine
#
# ----- diversity: 1.0
# ----- Generating with seed: "                    boxer vacate the rin"
#                     boxer vacate the rindle in you serry WINCES
#                          The very hard beer he bedroom, wolds dould toull
#                             Pumpkir my fuck dryin  MARSELLUS
#                          OPr hands Wonda fight, Marsellus' are sut a BROOKS
#                          Young Din't Mia turns are brgad of a seam the poor as
#                Co Bess, he's named to a neaws.
#
#                Lace.
#
#
# Epoch 14/50
# 7614/7614 [==============================] - 6s 787us/step - loss: 0.7989 - categorical_crossentropy: 0.7989 - acc: 0.7775
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: " no no, nothin' that
#                  "
#  no no, nothin' that
#
# ----- diversity: 0.5
# ----- Generating with seed: " no no, nothin' that
#                  "
#  no no, nothin' that
#                          Same was you a selfters and suach the wat the bedser.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " no no, nothin' that
#                  "
#  no no, nothin' that
#                          neadle, he, I've donnolded andin' he hass
#                          an when got the starter toward and stops her, out ahteadle
#                Whereing to give the stop, seed reads, for has phone)
#                          say it that Honda. Hears is I hase. Beens all youet a seet in
#                          to before theatherd endy's."Eecause all the apartment,
#
# Epoch 15/50
# 7614/7614 [==============================] - 6s 844us/step - loss: 0.7860 - categorical_crossentropy: 0.7860 - acc: 0.7806
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "                                   BUTCH"
#                                    BUTCH
#
# ----- diversity: 0.5
# ----- Generating with seed: "                                   BUTCH"
#                                    BUTCH
#                          What's his way. I'm the room, a fict
#                          I'm the shot!
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "                                   BUTCH"
#                                    BUTCH
#                          What'd ho were your towers to here,
#                          would means the backseep.
#
#                           are you've gronny. What we heart I gotta bet
#                Cow. Come! Douround gromnard what to him
#                          colpens. You want two the book, the
#                on his head to numal Macnoung just man, Zed
#                          I
# Epoch 16/50
# 7614/7614 [==============================] - 6s 839us/step - loss: 0.7749 - categorical_crossentropy: 0.7749 - acc: 0.7835
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "ks up to the bathroom door, which is par"
# ks up to the bathroom door, which is parkfact
#
# ----- diversity: 0.5
# ----- Generating with seed: "ks up to the bathroom door, which is par"
# ks up to the bathroom door, which is parking out of the front of
#
# ----- diversity: 1.0
# ----- Generating with seed: "ks up to the bathroom door, which is par"
# ks up to the bathroom door, which is parmsching.
#
#                                         manny.
#
#                The potell rissed a stops fuckey he timed up a truend in
#                it?
#
#                Vincent larem?
#
#                Not a specting from the reactons. He tomen guilly his fatront, he boits.
#
#                INT. RUSCA
#                          And JREAS of see-shopppect you're in a SaSCAWERS his pussonelwoull
# Epoch 17/50
# 7614/7614 [==============================] - 6s 841us/step - loss: 0.7648 - categorical_crossentropy: 0.7648 - acc: 0.7864
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "nto the motel parking lot. The rain
#   "
# nto the motel parking lot. The rain
#                          the street. I don't know what to the bathroom to
#
# ----- diversity: 0.5
# ----- Generating with seed: "nto the motel parking lot. The rain
#   "
# nto the motel parking lot. The rain
#                          Wanta know what the bag mosel down the car
#                                                                                                                                                                    Goddamn the bay.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "nto the motel parking lot. The rain
#   "
# nto the motel parking lot. The rain
#                          Don't be ny mouns it)
#                you're to Sabu awanneparts to get.
#                and tith on the busttis wich. Come of
#                have to himsele.
#
#                            Not those call comive. It's a fuckin' himsead evil fact.
#
#                You window watch have mean to dize
#                to himbll.
#
#                My Waing?
#
#                V
# Epoch 18/50
# 7614/7614 [==============================] - 6s 849us/step - loss: 0.7556 - categorical_crossentropy: 0.7556 - acc: 0.7884
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "                          VINCENT
#      "
#                           VINCENT
#
# ----- diversity: 0.5
# ----- Generating with seed: "                          VINCENT
#      "
#                           VINCENT
#                                                                                                                                             (to Right hangs up of the wall.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "                          VINCENT
#      "
#                           VINCENT
#                          Nomonorralf woolwaidesnat, hambledal full
#                          wideance fat you're "PRAPS how whist toward they're by
#                                           – I dylan one. It, holds ain't gral did up his loot
#                          comescom)
#                          So out the araire a six off.
#
#                                      ud as the LORDRAY behind bul
# Epoch 19/50
# 7614/7614 [==============================] - 7s 869us/step - loss: 0.7459 - categorical_crossentropy: 0.7459 - acc: 0.7910
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "y sometime. Me, I can't
#               "
# y sometime. Me, I can't
#                          the brought. I want that in the bad and
#                          the barrol. I have a trapped to
#
# ----- diversity: 0.5
# ----- Generating with seed: "y sometime. Me, I can't
#               "
# y sometime. Me, I can't
#
# ----- diversity: 1.0
# ----- Generating with seed: "y sometime. Me, I can't
#               "
# y sometime. Me, I can't
#                          can't gean countning, zendy of the drendy
#                band of here, be
#                          a tarth and ahpead, not in the corned cearact, he can happened you't
#                undexter.
#
#                Then Mac Lanca cop up a shot!
#
#                Mia's nobe.
#
#                Mia hold normans and bohing Marsellus.
#
#                The mmpomothing.
#
#                Mi
# Epoch 20/50
# 7614/7614 [==============================] - 6s 851us/step - loss: 0.7382 - categorical_crossentropy: 0.7382 - acc: 0.7929
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "nted car. Jules, you
#                  "
# nted car. Jules, you
#
# ----- diversity: 0.5
# ----- Generating with seed: "nted car. Jules, you
#                  "
# nted car. Jules, you
#
# ----- diversity: 1.0
# ----- Generating with seed: "nted car. Jules, you
#                  "
# nted car. Jules, you
#                          corr in.
#
#                Jimmie you're just old you des the troe their with the book.
#
#                                                                      inside, that was a alow 'til in and
#                          of back why stand how to Rove?
#
#                Mia, I well toh that to the high ONSPAY tRONTYNAMAN
#                               (hit like.
#
#
# Epoch 21/50
# 7614/7614 [==============================] - 6s 831us/step - loss: 0.7310 - categorical_crossentropy: 0.7310 - acc: 0.7952
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "         wearing cheap black suits with "
#          wearing cheap black suits with the
#
# ----- diversity: 0.5
# ----- Generating with seed: "         wearing cheap black suits with "
#          wearing cheap black suits with the Forred his head
#
# ----- diversity: 1.0
# ----- Generating with seed: "         wearing cheap black suits with "
#          wearing cheap black suits with her try you
#                                 JULES
#                          I thay you and hood what?
#
#                                                           JIMMIE
#                          QuiD
#                          Rothere, masharred excresciard out of the shit.
#
#                The musing thie -eepind, that off they're looks out of shit. This without
#                          Now
# Epoch 22/50
# 7614/7614 [==============================] - 7s 858us/step - loss: 0.7245 - categorical_crossentropy: 0.7245 - acc: 0.7961
#
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: " the table.
#
#                          "
#  the table.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " the table.
#
#                          "
#  the table.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: " the table.
#
#                          "
#  the table.
#
#                                                            (to She Benth bate my tapter Lance, rephaies as unta.
#
#                                              VINCENT
#                          On, for back precting alin' by the watch... Vincent when you sere is they, a front, Zed does a
#                          a cunicter.
#
#                                      VINCENT
#                                        JULES
#
# Epoch 23/50
# 7614/7614 [==============================] - 6s 825us/step - loss: 0.7179 - categorical_crossentropy: 0.7179 - acc: 0.7979
#
# ----- Generating text after Epoch: 22
# ----- diversity: 0.2
# ----- Generating with seed: "  Yes, but you're aware that there's
#  "
#   Yes, but you're aware that there's
#
# ----- diversity: 0.5
# ----- Generating with seed: "  Yes, but you're aware that there's
#  "
#   Yes, but you're aware that there's
#
# ----- diversity: 1.0
# ----- Generating with seed: "  Yes, but you're aware that there's
#  "
#   Yes, but you're aware that there's
#                          when, you know which the fucks this shit. We twite
#                continues destreat which time Man.
#
#                JULES
#                                   STOLLIMA
#
#                VINCENT
#                          The momos down on 'em. .
#
#                                      Lair STOG WOLF
#
#           COke didrenits rolling fight? We're juing to your all I doll
# Epoch 24/50
# 7614/7614 [==============================] - 6s 845us/step - loss: 0.7135 - categorical_crossentropy: 0.7135 - acc: 0.7991
#
# ----- Generating text after Epoch: 23
# ----- diversity: 0.2
# ----- Generating with seed: "ightening,
#                          Vi"
# ightening,
#                          Vincent takes a sup.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ightening,
#                          Vi"
# ightening,
#                          Vincent.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ightening,
#                          Vi"
# ightening,
#                          Vince hoh do down.
#
#                INT. VINCENT'S GRTEK RIGH Magus a fuckin',
#                          the lips as Aatill't INT. HORSEM DANE never STOMESS on the shot.
#
#                                      Good you did to start to we my now.
#
#                They're is shit in a stop. We to deadin'
#                from moss all glass was my budice washdles
#                          they pis
# Epoch 25/50
# 7614/7614 [==============================] - 7s 957us/step - loss: 0.7075 - categorical_crossentropy: 0.7075 - acc: 0.8009
#
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: "ollywood apartment
#                buil"
# ollywood apartment
#                building to the back to the box mosed.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "ollywood apartment
#                buil"
# ollywood apartment
#                building and blow the black don't be
#                          the bullets.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "ollywood apartment
#                buil"
# ollywood apartment
#                building and I'm. But that is says or and
#
#                Our to it has a drenty and stalf,
#                          keepec into Tanta threat in, I hear
#                          A gotta sup (over on accoater in his box moves like to you
#                floom.
#
#                                      (son-lildBUTTH4T
#                           That's one get pulls toride.
#
#                INT. M
# Epoch 26/50
# 7614/7614 [==============================] - 7s 949us/step - loss: 0.7027 - categorical_crossentropy: 0.7027 - acc: 0.8019
#
# ----- Generating text after Epoch: 25
# ----- diversity: 0.2
# ----- Generating with seed: "     THE CRAB MONSTER," and "MACHINE GUN"
#      THE CRAB MONSTER," and "MACHINE GUNNE
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "     THE CRAB MONSTER," and "MACHINE GUN"
#      THE CRAB MONSTER," and "MACHINE GUNING) – DAY
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "     THE CRAB MONSTER," and "MACHINE GUN"
#      THE CRAB MONSTER," and "MACHINE GUNNE
#
#                                      Fabvenie, so bug thing back.
#
#                                                                    "POLPS PERNS ote-lith? Both scare.
#                          He see show-deromra
#
#                Vincent Vincent-you knee that wath
#                          they acroboy shot!
#
#                                         with
#                did, they gi
# Epoch 27/50
# 7614/7614 [==============================] - 6s 827us/step - loss: 0.6980 - categorical_crossentropy: 0.6980 - acc: 0.8034
#
# ----- Generating text after Epoch: 26
# ----- diversity: 0.2
# ----- Generating with seed: "                                  VINCEN"
#                                   VINCENT
#                          They keep do that the speak to the door
#                          the street.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "                                  VINCEN"
#                                   VINCENT
#                          Okay it do.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "                                  VINCEN"
#                                   VINCENT
#                          The Doucting a tring that now.
#
#                He two fulloob, tock, Butch needssing the nggeder. He beop his all within his
#                          ton asta to you to like been love, the adrence)
#                          wold.
#
#                The Foom Maynall's and he kincandy.
#
#                                      PUMPKIN
#                          TTHE WALLY
# Epoch 28/50
# 7614/7614 [==============================] - 6s 779us/step - loss: 0.6929 - categorical_crossentropy: 0.6929 - acc: 0.8045
#
# ----- Generating text after Epoch: 27
# ----- diversity: 0.2
# ...
#                                                        YOUNG MAN
#                          Dar greether do you ready coffee. Antide?
#
#                                      the otherd.
#
#                                      Unda. It Gods an't that shit u
# Epoch 42/50
# 7614/7614 [==============================] - 6s 796us/step - loss: 0.6537 - categorical_crossentropy: 0.6537 - acc: 0.8145
#
# ----- Generating text after Epoch: 41
# ----- diversity: 0.2
# ----- Generating with seed: "egal to own
#                          i"
# egal to own
#                          it and Jules and Vincent and Mia way
#                          the shit in the word for the world.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "egal to own
#                          i"
# egal to own
#                          is that shit in the was thing.
#
#                                      JULES
#                          That's a your say "What?
#
#                                      I'm not no norms, I'm gonna count as
#                          were you is a med out of the way through
#                          the most be cool and Jules to a secule
#                          on the drind to me and you know wha
# ----- diversity: 1.0
# ----- Generating with seed: "egal to own
#                          i"
# egal to own
#                          is here, there's out.
#
#                The one. So have a lash, what is
#                the Herron.
#                                      It was shool, he's his what they do, and you go
#                                            (to Brett)
#                          Nox think I've a wallet – not now go on
#                          for him bag. You feel 'im for a
#                          gon
# Epoch 43/50
# 7614/7614 [==============================] - 6s 772us/step - loss: 0.6525 - categorical_crossentropy: 0.6525 - acc: 0.8149
#
# ----- Generating text after Epoch: 42
# ----- diversity: 0.2
# ----- Generating with seed: "                              VINCENT
#  "
#                               VINCENT
#
# ----- diversity: 0.5
# ----- Generating with seed: "                              VINCENT
#  "
#                               VINCENT
#                                             VINCENT
#
# ----- diversity: 1.0
# ----- Generating with seed: "                              VINCENT
#  "
#                               VINCENT
#                                    Did you to know, SLAMM BUTCH HALDINAG the tarth.  Min Bumptarfact. And ferous
#                                            What with the foot massage. Do Jummie's
#                crosses the Surc.
#
#                                                                              VINCENT
#                          What the black atherd to telk up to
#                I
# Epoch 44/50
# 7614/7614 [==============================] - 6s 782us/step - loss: 0.6502 - categorical_crossentropy: 0.6502 - acc: 0.8154
#
# ----- Generating text after Epoch: 43
# ----- diversity: 0.2
# ----- Generating with seed: "it, Jules –
#
#                          "
# it, Jules –
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "it, Jules –
#
#                          "
# it, Jules –
#
#                                      Butch strip?
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "it, Jules –
#
#                          "
# it, Jules –
#
#                                          That 'ea, is smolt road, Wont you not to bote, and thing nedds a
#                life in "Dinto rum untor if Forget my needle
#                through them. "It they's coffie. come of
#                of huletrose they says.
#
#                                      I homes and if your sux, let's gonna to!
#
#                                      gave be?
#
#
# Epoch 45/50
# 7614/7614 [==============================] - 6s 780us/step - loss: 0.6497 - categorical_crossentropy: 0.6497 - acc: 0.8160
#
# ----- Generating text after Epoch: 44
# ----- diversity: 0.2
# ----- Generating with seed: " He takes a sip, then, pacing as he thin"
#  He takes a sip, then, pacing as he think the restry on the
#                          that shit it, my head.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " He takes a sip, then, pacing as he thin"
#  He takes a sip, then, pacing as he think the ball garoon.
#
#                Butch pickin' you?
#
#                                                                                                                                                                                                                                                                                      Good in the big )
#                                      I'm the
# ----- diversity: 1.0
# ----- Generating with seed: " He takes a sip, then, pacing as he thin"
#  He takes a sip, then, pacing as he think her fisst
#                          princiner a can's else that hig as a daintly – on
#                          Given eyel accolvent just but they callbeer
#                          preber were me takin' his hund.
#
#                Vincent times hands or de.
#
#                She just mens in the litage both ota ged
#                          dead to actill.
#
#
# Epoch 46/50
# 7614/7614 [==============================] - 6s 784us/step - loss: 0.6481 - categorical_crossentropy: 0.6481 - acc: 0.8161
#
# ----- Generating text after Epoch: 45
# ----- diversity: 0.2
# ----- Generating with seed: "                                 FABIENN"
#                                  FABIENNE
#                          I don't know what the fuck a never see
#                          the back and the phone)
#                          I don't knew man, the mad the back and
#                          the bathroom to he car. The forget is the morning the car and
#                          the bank to the door see in the morning the car say.
#                          I'll be a big fuckin'
# ----- diversity: 0.5
# ----- Generating with seed: "                                 FABIENN"
#                                  FABIENNE
#                          I don't know what the name?
#
#                                                                                                                                                 MIA
#                          Oh your mirsel sound they call at the bad around.
#                          And the can shop way. A mit in the touch
#                          stands of the mannes a
# ----- diversity: 1.0
# ----- Generating with seed: "                                 FABIENN"
#                                  FABIENNE
#                          You tell him.
#
#                The zameel.
#
#                Mia lets. The two gotsame me orcent to grickt in her AGpece, the poxir are
#                austriend, one to sem to go tomay.
#                          How her we hourty
#                          but it's no no no no, no, no, no, no, house! WI derin in the coup.
#
#                Butch nolik's teers)
#
# Epoch 47/50
# 7614/7614 [==============================] - 6s 796us/step - loss: 0.6449 - categorical_crossentropy: 0.6449 - acc: 0.8172
#
# ----- Generating text after Epoch: 46
# ----- diversity: 0.2
# ----- Generating with seed: " me on a cellular
#                     "
#  me on a cellular
#                          the black charical about it, she
#                          the black champs the stairs are any of you
#                          the black char that had shit here,
#                          the shot.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " me on a cellular
#                     "
#  me on a cellular
#                          the real smart that's what I'm sayin'
#                          the story get a big blow?
#
#                                      What's he weak through the tellection.
#
#                                                                                                                                                                                                               come to be fucki
# ----- diversity: 1.0
# ----- Generating with seed: " me on a cellular
#                     "
#  me on a cellular
#                          two over to he's)
#
#                                      remember uself wantony howdong-asbo shoe mad poinon! Diess out that
#                how call sike?
#
#                Vince STARTS the bill up reach.
#
#                                      Dimber! The money?
#
#                                      On! Chaikners ain't doin', what eart
#                          see smile –
#
#
# Epoch 48/50
# 7614/7614 [==============================] - 6s 769us/step - loss: 0.6459 - categorical_crossentropy: 0.6459 - acc: 0.8160
#
# ----- Generating text after Epoch: 47
# ----- diversity: 0.2
# ----- Generating with seed: "in the red. Redline
#                   "
# in the red. Redline
#                          and have a smoke a bitch to him.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "in the red. Redline
#                   "
# in the red. Redline
#                          there looks at his continues to a
#                          on the ground)
#                          Well, she did you got at the
#
# ----- diversity: 1.0
# ----- Generating with seed: "in the red. Redline
#                   "
# in the red. Redline
#                                      YeaTh miniblie'm letem detor window.
#
#                                             Whonena friend mirror?
#
#               of at the mirmoril lookin' first and
#                          twan, now. Bot whet. I need you is
#                          a fuckin' die in becan.
#
#                                      FABIENNE
#                          Well. Ind way through the Chover
# Epoch 49/50
# 7614/7614 [==============================] - 6s 775us/step - loss: 0.6432 - categorical_crossentropy: 0.6432 - acc: 0.8172
#
# ----- Generating text after Epoch: 48
# ----- diversity: 0.2
# ----- Generating with seed: " dressed.
#                          The"
#  dressed.
#                          The two men stand is the shot.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " dressed.
#                          The"
#  dressed.
#                          The taxine. Resses in the two men siruie
#                          fuckin' do exact think that means the
#                          the dance flaporriunly in the car know. A youn
#                          pancicleme WHIPS the cart. He looks at him and starts pancakes and
#                          he seen hit informaliscome shots the table and
#                          what was shake doll anything
# ----- diversity: 1.0
# ----- Generating with seed: " dressed.
#                          The"
#  dressed.
#                          The Jody and think you have Mia I can
#                          upin are stanks fanns?
#
#                                      What we ever handle it leave. This leaving
#                          that some towars the shirts are any orreybord stiels,
#                          what looking for think her
#                          here he couldn't lays yaloocy, will.
#
#
# Epoch 50/50
# 7614/7614 [==============================] - 6s 785us/step - loss: 0.6417 - categorical_crossentropy: 0.6417 - acc: 0.8177
#
# ----- Generating text after Epoch: 49
# ----- diversity: 0.2
# ----- Generating with seed: "             yourself, but when two men "
#              yourself, but when two men hanger and
#                          and seling out of the street with a
#                          could be for the street in the bedroom leaving on
#                          the story.  I'll be fuckin' place looking a
#                          and seling care of the car off the call God make. Vincent
#                          and seriously get the same get in
#                          and t
# ----- diversity: 0.5
# ----- Generating with seed: "             yourself, but when two men "
#              yourself, but when two men a big love to
#                          as she think it's a slight we did your
#                          a big black sits and says: "DY SLOWS in the cabbied.
#
#                                                                                                                                                                                     MARSELLUS
#                               (place the start
# ----- diversity: 1.0
# ----- Generating with seed: "             yourself, but when two men "
#              yourself, but when two men hamped down.
#
#                               (sics?
#
#                          Yeah man, the table do it that way.
#                          right?
#
#                                      VINCENT
#                          She manes her a word.
#
#                                      VINCENT
#                          100%.
#
#                                      are crying a word.

# %%
# %tensorboard --logdir logs_week5/
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:6006"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# > **Ex. 5.1.2**: Add a callback for Tensorboard, so you can log the training process. Start training the network (takes ~10 minutes on my computer). While it's running move on to the next question.

# %% [markdown]
# > **Ex. 5.1.3**: Answer the questions in the code above (look for code comments starting with `Q:`).

# %% [markdown]
# > **Ex. 5.1.4**: Did the network finish training? Consider the generated text across epochs.
# 1. In the early batches (0-10), the generated text looks very bad. Can you explain why the low diversity generated text contains almost only the symbol " " (that is, spaces)?
# 2. The high diversity generated text is messed up too, but in a different way. Explain how.
# 3. In later batches (20-30) what do you notice is off about the low diversity generated text?

# %% [markdown]
# >> the low diversity (almost only contains the symbol " ") is due to the high density of spaces in the original text. With little training, the model tries to insert more spaces because its probability of occurring is highest.

# %% [markdown]
# > **Ex. 5.1.5**: For the network trained over all 50 epochs, generate a longer piece of text
# (say 5000 symbols long). Use the sentence `text[1486:1526]` as seed (starts with 'YOUNG MAN' ends with 'No, ')
# and set diversity to 0.5.
# Describe what features of the screenplay and language in general that the network learned in only 50 epochs.
# Also describe what serious mistakes it makes.

# %%
start_index = 1486
seqlen = 40

# Q5: What does diversity do?
# A5: picks a float in the list to divide the predictions by to give chance for possible local minima escape
diversity = 0.5
print('----- diversity:', diversity)

generated = ''
sentence = text[start_index: start_index + seqlen]
generated += sentence
print('----- Generating with seed: "' + sentence + '"')
sys.stdout.write(generated)

for i in range(5000):
    x_pred = np.zeros((1, seqlen, len(chars)))
    for t, char in enumerate(sentence):
        x_pred[0, t, char_indices[char]] = 1.

    # What is the dimensionality of `preds`? Why do we input `preds[0, -1]` to the `sample` function?
    preds = model.predict(x_pred, verbose=0)
    next_index = sample(preds[0, -1], diversity)
    next_char = indices_char[next_index]

    sentence = sentence[1:] + next_char

    sys.stdout.write(next_char)
    sys.stdout.flush()
print()
# Out:
# ----- diversity: 0.5
# ----- Generating with seed: "YOUNG MAN
#                          No, "
# YOUNG MAN
#                          No, I miral was a boldoway.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   the cartauran fuckin' fannents the bad, sits a
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    motherfuckers at the black suitchich is,
#                          place looks up a huge stands up. She beding
#                          a momma blace gettin' her the one of the car of the him a sece of the bedroom it

# %% [markdown]
# > **Ex. 5.1.6**: Do the same as above, but for 40 random letters (e.g. smash away on your keyboard) as seed. What happens? Can you explain why?

# %%
seed = "oijawef wefijwe oujioa woo w dfaosij efk"
len(seed)

# Q5: What does diversity do?
# A5: picks a float in the list to divide the predictions by to give chance for possible local minima escape
diversity = 0.5
print('----- diversity:', diversity)

generated = ''
sentence = seed
generated += sentence
print('----- Generating with seed: "' + sentence + '"')
sys.stdout.write(generated)

for i in range(5000):
    x_pred = np.zeros((1, seqlen, len(chars)))
    for t, char in enumerate(sentence):
        x_pred[0, t, char_indices[char]] = 1.

    # What is the dimensionality of `preds`? Why do we input `preds[0, -1]` to the `sample` function?
    preds = model.predict(x_pred, verbose=0)
    next_index = sample(preds[0, -1], diversity)
    next_char = indices_char[next_index]

    sentence = sentence[1:] + next_char

    sys.stdout.write(next_char)
    sys.stdout.flush()
print()
# Out:
# ----- diversity: 0.5
# ----- Generating with seed: "oijawef wefijwe oujioa woo w dfaosij efk"
# oijawef wefijwe oujioa woo w dfaosij efker
#                          the stares. He leanters windows. The
#                          all you would leave wo know what the
#                          a same every one of the car, walk a
#                          and sering to him.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           BUTCH
#                          I don't be clothes is a secention this
#                          and the bathroom like.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              MIA
#                          She to see the sitting me to go it anybody
#                          on the mask at the bottonally
#                          anybody inside the two men the same
#                          a fuck about the Sursing cheas a back the
#                          and see shit like a mome the cord cotfod his
#                anyway. The first sings.
#
#                                                              BUTCH
#                          Leach out, get your grandfather her it. I'm
#                          is the street thing and see seems to be
#                          you don't you get the match bed the bedroom.
#
#                                      The Gimp getta leave. I hang. Why 'launge,
#                          motherfucker. You're don't see Jules and
#                          on the street in the bedroom little kit's
#                          inside the street with the earle,
#                          and selfish. But let's get it still
#                          ears a lot of the trunking powning the bed in a
#                          meaning behind with the street with
#                          gouta case of the car she could ragr bag
#                          the same get it ailline of for the
#                          the same bed.

# %% [markdown]
# > **Challenge** Download [this](https://www.yelp.com/dataset/download) Yelp dataset and train a model that predicts rating given a review text!
